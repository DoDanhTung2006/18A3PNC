# %%
from tkinter import Tk, Label

window = Tk() 
window.title("Window") 

lbl = Label(window, text="Hello Uneti", font=("Arial Bold", 20))

window.geometry('280x80') 

lbl.grid(column=0, row=0) 
window.mainloop()
