# %%
import threading
import requests
import time
URLS = [
    'https://www.example.com',
    'https://www.example.org',
    'https://www.example.net'
]

def fetch_url(url):
    thread_name = threading.current_thread().name
    try:
        start_time = time.time()
        response = requests.get(url, timeout=5) 
        end_time = time.time()
        
        status = response.status_code
        length = len(response.text)
        
        print(f"[{thread_name}] ✅ {url}: Status={status}, Kích thước={length} bytes, Thời gian={end_time - start_time:.2f}s")
        
    except requests.exceptions.RequestException as e:
        print(f"[{thread_name}] ❌ Lỗi khi truy cập {url}: {e}")

def main():
    threads = []
    print(f"THỰC HIỆN {len(URLS)} YÊU CẦU HTTP ĐỒNG THỜI ---")

    start_total = time.time()

    for url in URLS:
        thread = threading.Thread(target=fetch_url, args=(url,))
        threads.append(thread)
        thread.start()

    for thread in threads:
        thread.join()

    end_total = time.time()
    print(f"\nTổng thời gian hoàn thành (Đa luồng): {end_total - start_total:.2f} giây.")

main()
# Out:
# THỰC HIỆN 3 YÊU CẦU HTTP ĐỒNG THỜI ---
# [Thread-3 (fetch_url)] ✅ https://www.example.com: Status=200, Kích thước=513 bytes, Thời gian=1.15s
# [Thread-4 (fetch_url)] ✅ https://www.example.org: Status=200, Kích thước=513 bytes, Thời gian=1.19s
# [Thread-5 (fetch_url)] ✅ https://www.example.net: Status=200, Kích thước=513 bytes, Thời gian=1.25s
#
# Tổng thời gian hoàn thành (Đa luồng): 1.25 giây.
