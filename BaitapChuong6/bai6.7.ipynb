# %%
import threading
import datetime

def google():
    for i in range(3):
        print("Google: Web", datetime.datetime.now())

def yahoo():
    for i in range(3):
        print("Yahoo: Web", datetime.datetime.now())

def facebook():
    for i in range(3):
        print("Facebook: Web", datetime.datetime.now())

def main():
    t1 = threading.Thread(target=google)
    t2 = threading.Thread(target=yahoo)
    t3 = threading.Thread(target=facebook)

    t1.start()
    t2.start()
    t3.start()

    t1.join()
    t2.join()
    t3.join()

main()
# Out:
# Google: Web 2025-12-30 22:19:25.299883
# Google: Web 2025-12-30 22:19:25.303303
# Google: Web 2025-12-30 22:19:25.303342
# Yahoo: Web 2025-12-30 22:19:25.303544
# Yahoo: Web 2025-12-30 22:19:25.303628
# Yahoo: Web 2025-12-30 22:19:25.303669
# Facebook: Web 2025-12-30 22:19:25.304413
# Facebook: Web 2025-12-30 22:19:25.304491
# Facebook: Web 2025-12-30 22:19:25.304656
