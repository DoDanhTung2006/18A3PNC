# %%
import threading
import time 
lock = threading.Lock()
can_print_even = True 

def in_so_chan(max_num):
    global can_print_even
    for i in range(2, max_num + 1, 2):
        with lock:
            while not can_print_even:
                lock.release() 
                time.sleep(0.001)
                lock.acquire()
                
            print(f"[Luồng CHẴN] {i}")
            can_print_even = False 
def in_so_le(max_num):
    global can_print_even
    for i in range(1, max_num + 1, 2):
        with lock:
            while can_print_even:
                lock.release()
                time.sleep(0.001)
                lock.acquire()
                
            print(f"[Luồng LẺ] {i}")
            can_print_even = True 

def bai_6_6_in_xen_ke_chan_le(max_num=20):
    global can_print_even, lock
    can_print_even = True 
    lock = threading.Lock()
    
    print(f"IN SỐ CHẴN/LẺ XEN KẼ ĐẾN {max_num}")

    t_chan = threading.Thread(target=in_so_chan, args=(max_num,), name="Even_Thread")
    t_le = threading.Thread(target=in_so_le, args=(max_num,), name="Odd_Thread")
    
    t_le.start() 
    t_chan.start() 
    
    t_chan.join()
    t_le.join()

    print("\nQuá trình in xen kẽ đã hoàn thành")
bai_6_6_in_xen_ke_chan_le(10)
# Out:
# IN SỐ CHẴN/LẺ XEN KẼ ĐẾN 10
# [Luồng CHẴN] 2
# [Luồng LẺ] 1
# [Luồng CHẴN] 4
# [Luồng LẺ] 3
# [Luồng CHẴN] 6
# [Luồng LẺ] 5
# [Luồng CHẴN] 8
# [Luồng LẺ] 7
# [Luồng CHẴN] 10
# [Luồng LẺ] 9
#
# Quá trình in xen kẽ đã hoàn thành
