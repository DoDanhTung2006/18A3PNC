# %%
from threading import Thread
from datetime import datetime
import time

def print_message(thread_name):
    for i in range(3):
        print(f"{thread_name}: Web {datetime.now().strftime('%b %d %H:%M:%S %Y')}")
        time.sleep(1)

    print(f"Exiting {thread_name}")

def main():
    print("Starting Main Thread")

    threads = []

    thread_names = ["Google", "Yahoo", "Facebook"]

    for name in thread_names:
        thread = Thread(target=print_message, args=(name,))
        threads.append(thread)
        thread.start()

    for thread in threads:
        thread.join()

    print("Main Thread")
    print("Exiting")

main()
# Out:
# Starting Main Thread
# Google: Web Dec 30 22:19:00 2025
# Yahoo: Web Dec 30 22:19:00 2025
# Facebook: Web Dec 30 22:19:00 2025
# Google: Web Dec 30 22:19:01 2025Yahoo: Web Dec 30 22:19:01 2025
# Facebook: Web Dec 30 22:19:01 2025
#
# Facebook: Web Dec 30 22:19:02 2025
# Yahoo: Web Dec 30 22:19:02 2025
# Google: Web Dec 30 22:19:02 2025
# Exiting Yahoo
# Exiting Google
# Exiting Facebook
# Main Thread
# Exiting
